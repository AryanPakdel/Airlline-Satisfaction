# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")
df_full = pd.concat([df_train,df_test])

# %%
df_full.head(10)
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
# 5           5  111157  Female     Loyal Customer   26  Personal Travel
# 6           6   82113    Male     Loyal Customer   47  Personal Travel
# 7           7   96462  Female     Loyal Customer   52  Business travel
# 8           8   79485  Female     Loyal Customer   41  Business travel
# 9           9   65725    Male  disloyal Customer   20  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# ...

# %%
print("Dataset Shape:", df_full.shape)
print(f"Rows: {df_full.shape[0]}\nColumns: {df_full.shape[1]}")
# Out:
# Dataset Shape: (129880, 25)
# Rows: 129880
# Columns: 25

# %%
print("Droping Useless Columns")
df_full.drop(columns=["Unnamed: 0" , "id"],axis = 1,inplace=True)
# Out:
# Droping Useless Columns

# %%
print("\nBasic Info:")
df_full.info()
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129880 entries, 0 to 25975
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Inflight wifi service              129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Ease of Online booking             129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Food and drink                     129880 non-null  int64
# ...

# %%
print("\nStatistical Summary (Numerical):")
df_full.describe()
# Out:
# Statistical Summary (Numerical):
#                  Age  Flight Distance  Inflight wifi service  \
# count  129880.000000    129880.000000          129880.000000
# mean       39.427957      1190.316392               2.728696
# std        15.119360       997.452477               1.329340
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       844.000000               3.000000
# 75%        51.000000      1744.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# min                             0.000000                0.000000
# ...

# %%
print("\nMissing Values:")
df_full.isna().sum()
# Out:
# Missing Values:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# ...

# %%
print(f"Missing Value Percentage in Arrival Delay Column : {df_full["Arrival Delay in Minutes"].isna().sum()/df_full["Arrival Delay in Minutes"].count()*100:.2f}%")
# Out:
# Missing Value Percentage in Arrival Delay Column : 0.30%

# %%
df_full.dropna(inplace=True)

# %%
df_full.count()
# Out:
# Gender                               129487
# Customer Type                        129487
# Age                                  129487
# Type of Travel                       129487
# Class                                129487
# Flight Distance                      129487
# Inflight wifi service                129487
# Departure/Arrival time convenient    129487
# Ease of Online booking               129487
# Gate location                        129487
# Food and drink                       129487
# Online boarding                      129487
# Seat comfort                         129487
# Inflight entertainment               129487
# On-board service                     129487
# Leg room service                     129487
# Baggage handling                     129487
# Checkin service                      129487
# Inflight service                     129487
# Cleanliness                          129487
# Departure Delay in Minutes           129487
# ...

# %%
duplicates = df_full.duplicated()
print(f"Number of duplicate rows: {duplicates.sum()}")
# Out:
# Number of duplicate rows: 0

# %%
print("\nSatisfaction(Target) Class Distribution:\n")

print(df_full.satisfaction.value_counts(),"\n")
satisfaction_percentage = df_full['satisfaction'].value_counts(normalize=True)
print(satisfaction_percentage.apply(lambda x: f"{x*100:.2f}%"))

sns.countplot(x='satisfaction', data=df_full)
plt.title("Satisfaction Class Distribution")
plt.show()
# Out:
# Satisfaction(Target) Class Distribution:
#
# satisfaction
# neutral or dissatisfied    73225
# satisfied                  56262
# Name: count, dtype: int64
#
# satisfaction
# neutral or dissatisfied    56.55%
# satisfied                  43.45%
# Name: proportion, dtype: object

# %%
satisfaction_counts = df_full['satisfaction'].value_counts()

# Plot the pie chart
satisfaction_counts.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), startangle=90, colors=['skyblue', 'orange'])
plt.title('Distribution of Satisfaction Levels')
plt.ylabel('')  # Hide the y-label for better aesthetics
plt.show()

# %%
print("Histograms for all numerical features")
df_full.hist(figsize=(15, 15),bins=30 ,edgecolor='black')
plt.show()
# Out:
# Histograms for all numerical features

# %%
x = df_full.drop(columns="satisfaction",axis=1)
x.shape
# Out:
# (129487, 22)

# %%
y = df_full["satisfaction"]
y.shape
# Out:
# (129487,)

# %%
categorical_features = x.select_dtypes(include=['object']).columns
print(categorical_features)
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class'], dtype='object')

# %%
numerical_features = df_full.select_dtypes(include=['number']).columns
print(numerical_features)
# Out:
# Index(['Age', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
print("Categorical Columns : ")
for col in categorical_features:
    print(f"{col}  =  {df_full[col].unique()}")
# Out:
# Categorical Columns :
# Gender  =  ['Male' 'Female']
# Customer Type  =  ['Loyal Customer' 'disloyal Customer']
# Type of Travel  =  ['Personal Travel' 'Business travel']
# Class  =  ['Eco Plus' 'Business' 'Eco']

# %%
age_satisfaction_crosstab = pd.crosstab(df_full['Age'], df_full['satisfaction'])

# Bar chart visualization
age_satisfaction_crosstab.plot(kind='bar', figsize=(20, 10))
plt.title('Crosstab of Age and Satisfaction')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Satisfaction')
plt.show()

# %%
gender_satisfaction_crosstab = pd.crosstab(df_full['Gender'], df_full['satisfaction'])

# Bar chart visualization
gender_satisfaction_crosstab.plot(kind='bar', figsize=(12, 6))
plt.title('Crosstab of Gender and Satisfaction')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Satisfaction')
plt.show()

# %%
sns.histplot(df_full, x = "Age", hue = "Customer Type", multiple = "stack", palette = "YlOrBr", edgecolor = ".3", linewidth = .5)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df_numerical = df_full[numerical_features]
correlation_matrix = df_numerical.corr()

# Plot the heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', cbar=True, square=True)
plt.title('Correlation Matrix for Numerical Features')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_full['Arrival Delay in Minutes'], df_full['Departure Delay in Minutes'], alpha=0.5, c='blue', edgecolor='k')
plt.title('Scatter Plot of Arrival vs. Departure Delay')
plt.xlabel('Arrival Delay in Minutes')
plt.ylabel('Departure Delay in Minutes')
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
column_transformer = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(dtype=int), categorical_features)
    ],
    remainder='passthrough'
)

# %%
transformed_x = column_transformer.fit_transform(x)

# %%
transformed_x
# Out:
# array([[ 0.,  1.,  1., ...,  5., 25., 18.],
#        [ 0.,  1.,  0., ...,  1.,  1.,  6.],
#        [ 1.,  0.,  1., ...,  5.,  0.,  0.],
#        ...,
#        [ 1.,  0.,  1., ...,  2.,  0.,  0.],
#        [ 0.,  1.,  1., ...,  4.,  0.,  0.],
#        [ 1.,  0.,  1., ...,  1.,  0.,  0.]])

# %%
encoded_columns = column_transformer.get_feature_names_out()
x = pd.DataFrame(transformed_x, columns=encoded_columns)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129487 entries, 0 to 129486
# Data columns (total 27 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   onehot__Gender_Female                         129487 non-null  float64
#  1   onehot__Gender_Male                           129487 non-null  float64
#  2   onehot__Customer Type_Loyal Customer          129487 non-null  float64
#  3   onehot__Customer Type_disloyal Customer       129487 non-null  float64
#  4   onehot__Type of Travel_Business travel        129487 non-null  float64
#  5   onehot__Type of Travel_Personal Travel        129487 non-null  float64
#  6   onehot__Class_Business                        129487 non-null  float64
#  7   onehot__Class_Eco                             129487 non-null  float64
#  8   onehot__Class_Eco Plus                        129487 non-null  float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
y = LabelEncoder().fit_transform(y)

# %%
y.shape
# Out:
# (129487,)

# %%
x.shape
# Out:
# (129487, 27)

# %%
from sklearn.model_selection import train_test_split
np.random.seed(42)

#train & test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

#train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

print(f"Training Set: X_train = {X_train.shape}, y_train = {y_train.shape}")
print(f"Validation Set: X_val = {X_val.shape}, y_val = {y_val.shape}")
print(f"Test Set: X_test = {X_test.shape}, y_test = {y_test.shape}")
# Out:
# Training Set: X_train = (82871, 27), y_train = (82871,)
# Validation Set: X_val = (20718, 27), y_val = (20718,)
# Test Set: X_test = (25898, 27), y_test = (25898,)

# %%
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score


rf_model = RandomForestClassifier(random_state=42)
lr_model = LogisticRegression(max_iter=2000, solver='saga',random_state=42)
xgb_model = xgb.XGBClassifier(random_state=42)

rf_model.fit(X_train, y_train)
lr_model.fit(X_train, y_train)
xgb_model.fit(X_train, y_train)

rf_pred = rf_model.predict(X_val)
lr_pred = lr_model.predict(X_val)
xgb_pred = xgb_model.predict(X_val)

rf_accuracy = accuracy_score(y_val, rf_pred)
lr_accuracy = accuracy_score(y_val, lr_pred)
xgb_accuracy = accuracy_score(y_val, xgb_pred)
print(f"Random Forest Accuracy: {rf_accuracy:.4f}")
print(f"Logistic Regression Accuracy: {lr_accuracy:.4f}")
print(f"XGBoost Accuracy: {xgb_accuracy:.4f}")
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Random Forest Accuracy: 0.9619
# Logistic Regression Accuracy: 0.8349
# XGBoost Accuracy: 0.9626

# %%
from sklearn.model_selection import GridSearchCV

param_grid_rf = {
    'n_estimators': [100, 200, 300],       
    'max_depth': [None, 10, 20, 30],         
    'min_samples_split': [2, 5, 10],         
    'min_samples_leaf': [1, 2, 4]            
}

grid_search_rf = GridSearchCV(estimator=RandomForestClassifier(random_state=42),
                              param_grid=param_grid_rf, 
                              cv=5,             
                              scoring='accuracy',  
                              n_jobs=-1,        
                              verbose=2)


grid_search_rf.fit(X_train, y_train)
print("Best Random Forest Parameters:", grid_search_rf.best_params_)
print("Best Random Forest Accuracy:", grid_search_rf.best_score_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Random Forest Parameters: {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Best Random Forest Accuracy: 0.9627976086406939

# %%
param_dist_lr = {
    'C': [0.01, 0.1, 1, 10],   
    'penalty': ['l1', 'l2']    
}

random_search_lr = GridSearchCV(estimator=LogisticRegression(max_iter=2000, solver='saga', random_state=42),
                                      param_grid=param_dist_lr,
                                      cv=5,                   
                                      scoring='accuracy',     
                                      n_jobs=-1,        
                                      verbose=2)


random_search_lr.fit(X_train, y_train)
print("Best Logistic Regression Parameters:", random_search_lr.best_params_)
print("Best Logistic Regression Accuracy:", random_search_lr.best_score_)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Best Logistic Regression Parameters: {'C': 0.01, 'penalty': 'l2'}
# Best Logistic Regression Accuracy: 0.8303266454700806
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
param_grid_xgb = {
    'n_estimators': [100, 200],      
    'max_depth': [3, 6],            
    'learning_rate': [0.05, 0.1],   
    'subsample': [0.8, 1.0],          
    'colsample_bytree': [0.8, 1.0]     
}


grid_search_xgb = GridSearchCV(estimator=xgb.XGBClassifier(tree_method="hist",device="cuda",random_state=42),
                               param_grid=param_grid_xgb,
                               cv=5,               
                               scoring='accuracy',
                               n_jobs=-1,         
                               verbose=2)


grid_search_xgb.fit(X_train, y_train)
print("Best XGBoost Parameters:", grid_search_xgb.best_params_)
print("Best XGBoost Accuracy:", grid_search_xgb.best_score_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Best XGBoost Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 1.0}
# Best XGBoost Accuracy: 0.9635819653199391

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve


def evaluate_model(model, X_val, y_val):
    y_pred = model.predict(X_val)
    y_proba = model.predict_proba(X_val)[:, 1] 
    print("Confusion Matrix:")
    print(confusion_matrix(y_val, y_pred))
    print("\nClassification Report:")
    print(classification_report(y_val, y_pred))
    print("ROC AUC Score:", roc_auc_score(y_val, y_proba))

    fpr, tpr, thresholds = roc_curve(y_val, y_proba)
    plt.figure(figsize=(10, 6))
    plt.plot(fpr, tpr, label=f'{model.__class__.__name__} (AUC = {roc_auc_score(y_val, y_proba):.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  # Random chance line
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    plt.show()

print("Random Forest:")
evaluate_model(rf_model, X_val, y_val)
print("\nLogistic Regression:")
evaluate_model(lr_model, X_val, y_val)
print("\nXGBoost:")
evaluate_model(xgb_model, X_val, y_val)
# Out:
# Random Forest:
# Confusion Matrix:
# [[11411   254]
#  [  535  8518]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     11665
#            1       0.97      0.94      0.96      9053
#
#     accuracy                           0.96     20718
#    macro avg       0.96      0.96      0.96     20718
# weighted avg       0.96      0.96      0.96     20718
#
# ROC AUC Score: 0.9941607476171779
# Logistic Regression:
# Confusion Matrix:
# [[9834 1831]
#  [1589 7464]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85     11665
#            1       0.80      0.82      0.81      9053
#
#     accuracy                           0.83     20718
#    macro avg       0.83      0.83      0.83     20718
# weighted avg       0.84      0.83      0.84     20718
#
# ROC AUC Score: 0.8960328823228869
# XGBoost:
# Confusion Matrix:
# ...

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def plot_confusion_matrix_heatmap(y_true, y_pred, model_name):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['False', 'True'])
    plt.title(f'Confusion Matrix for {model_name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

print("Random Forest Confusion Matrix Heatmap:")
plot_confusion_matrix_heatmap(y_val, rf_pred, 'Random Forest')

print("Logistic Regression Confusion Matrix Heatmap:")
plot_confusion_matrix_heatmap(y_val, lr_pred, 'Logistic Regression')

print("XGBoost Confusion Matrix Heatmap:")
plot_confusion_matrix_heatmap(y_val, xgb_pred, 'XGBoost')
# Out:
# Random Forest Confusion Matrix Heatmap:
# Logistic Regression Confusion Matrix Heatmap:
# XGBoost Confusion Matrix Heatmap:

# %%
rf_report = classification_report(y_val, rf_pred, output_dict=True)
lr_report = classification_report(y_val, lr_pred, output_dict=True)
xgb_report = classification_report(y_val, xgb_pred, output_dict=True)

# Extract metrics for the "Positive" class (label = 1)
rf_precision = rf_report['1']['precision']
rf_recall = rf_report['1']['recall']
rf_f1 = rf_report['1']['f1-score']

lr_precision = lr_report['1']['precision']
lr_recall = lr_report['1']['recall']
lr_f1 = lr_report['1']['f1-score']

xgb_precision = xgb_report['1']['precision']
xgb_recall = xgb_report['1']['recall']
xgb_f1 = xgb_report['1']['f1-score']

rf_pred_prob = rf_model.predict_proba(X_val)[:, 1]
lr_pred_prob = lr_model.predict_proba(X_val)[:, 1]
xgb_pred_prob = xgb_model.predict_proba(X_val)[:, 1]

rf_auc_score = roc_auc_score(y_val, rf_pred_prob)
lr_auc_score = roc_auc_score(y_val, lr_pred_prob)
xgb_auc_score = roc_auc_score(y_val, xgb_pred_prob)

results = {
    'Model': ['Random Forest', 'Logistic Regression', 'XGBoost'],
    'Accuracy': [rf_accuracy, lr_accuracy, xgb_accuracy],
    'Precision': [rf_precision, lr_precision, xgb_precision],  
    'Recall': [rf_recall, lr_recall, xgb_recall],              
    'F1-Score': [rf_f1, lr_f1, xgb_f1],                      
    'AUC':[ rf_auc_score, lr_auc_score, xgb_auc_score]             
}

comparison_df = pd.DataFrame(results)
comparison_df
# Out:
#                  Model  Accuracy  Precision    Recall  F1-Score       AUC
# 0        Random Forest  0.961917   0.971044  0.940904  0.955736  0.994161
# 1  Logistic Regression  0.834926   0.803012  0.824478  0.813604  0.896033
# 2              XGBoost  0.962593   0.970876  0.942671  0.956566  0.995149

# %%
best_model = rf_model  # Replace with the best model 

test_pred = best_model.predict(X_test)
test_proba = best_model.predict_proba(X_test)[:, 1]
print("Test Set Evaluation:")
print("Accuracy:", accuracy_score(y_test, test_pred))
print("ROC AUC:", roc_auc_score(y_test, test_proba))
print("Classification Report:")
print(classification_report(y_test, test_pred))
# Out:
# Test Set Evaluation:
# Accuracy: 0.9614642057301722
# ROC AUC: 0.9938160189517298
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     14668
#            1       0.97      0.94      0.95     11230
#
#     accuracy                           0.96     25898
#    macro avg       0.96      0.96      0.96     25898
# weighted avg       0.96      0.96      0.96     25898

# %%
import joblib

joblib.dump(best_model, 'best_model.pkl')
# Out:
# ['best_model.pkl']
